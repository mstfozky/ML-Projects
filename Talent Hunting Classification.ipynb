# %%
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 8.0 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate, cross_val_score, validation_curve
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 170)
pd.set_option('display.max_rows', 20)
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
from google.colab import drive
drive.mount('/content/drive')

df1 = pd.read_csv("/content/drive/MyDrive/Dataset/scoutium_attributes.csv", sep=";")
df2 = pd.read_csv("/content/drive/MyDrive/Dataset/scoutium_potential_labels.csv", sep=";")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.merge(df1, df2, left_index=True, right_index=True)

# %%
df.head()
# Out:
#    task_response_id_x  match_id_x  evaluator_id_x  player_id_x  position_id  analysis_id  attribute_id  attribute_value  task_response_id_y  match_id_y  evaluator_id_y  \
# 0                4915       62935          177676      1361061            2     12818495          4322           56.000                4915       62935          177676
# 1                4915       62935          177676      1361061            2     12818495          4323           56.000                4915       62935          177676
# 2                4915       62935          177676      1361061            2     12818495          4324           67.000                4915       62935          177676
# 3                4915       62935          177676      1361061            2     12818495          4325           56.000                4915       62935          177676
# ...

# %%
new_df = df[df['potential_label'] != 'below_average']

# %%
pivot_table = pd.pivot_table(df, index=['player_id_x'], columns=['potential_label'], aggfunc='count', fill_value=0)
print(pivot_table)
# Out:
#                 analysis_id                           attribute_id                           attribute_value                           evaluator_id_x                \
# potential_label     average below_average highlighted      average below_average highlighted         average below_average highlighted        average below_average
# player_id_x
# 1361061                  24             1           9           24             1           9              24             1           9             24             1
# 1361626                  26             0           8           26             0           8              26             0           8             26             0
# 1361858                  26             1           7           26             1           7              26             1           7             26             1
# ...
